# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCapComp/Atividades/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### ----- TUtorial ----- ###
personagens1 = {
    "Senhor dos Anais": {"vida": 150, "salario": 200, "defesa": 200},
    "Cumpadi Washington": {"vida": 250, "salario": 400, "defesa": 300},
    "1155 ET": {"vida": 10, "salario": 550, "defesa": 500}
}
print("---# Bem vindo ao Brasawood!! #---\n")
escolha = input("Escolha sua classe\nSenhor dos Anais\nCumpadi Washington\n1155 ET\n")

if escolha in personagens1:
  jogador = personagens1[escolha]
  print(f"vc escolheu o {escolha},\nstatus: {jogador}")
else:
  print("classe não encontrada, por falta de escolha, vc virará um bolsonaro!!(fraquin)")
  jogador ={"vida": 100, "salario": 5, "defesa": 5}

inimigo = {"nome": "Boletos", "vida": 200, "divida": 100}
print(f"A NAAAAAAAAAAAAAO!!! OS BOLETOS APARECEUUU!!")

while jogador ['vida'] > 0 and inimigo['vida'] > 0:
  print("\n O zé, ve se nao se endivida, paga esse cara logo!!")
  acao = input("mentalize 'A' para pagar ou 'F' para fugir e ficar com o\nnome no serasa durante o resto da sua vida").upper()

  if acao == 'A':
    dano = jogador['salario']
    inimigo['vida'] -= dano
    print(f"voce pagou uma parcela de R${dano}!!\nSua divida abaixa para {inimigo['vida']}")
  else:
    print('Oc não pagou e agr os homi ta atras doc até q vc descore q é um esqueleto e acaba sendo morto')

  if inimigo['vida'] > 0:
    dano_inimigo = inimigo['divida'] - jogador['defesa']
    if dano_inimigo < 0: dano_inimigo = 0

    jogador['vida'] -= dano_inimigo
    print(f"os boletos chegaram mais caros esse mes!! seu saldo atual {jogador['vida']}")

  if jogador ['vida'] <= 0:
    print("\n  VAI VIRA MENDINGO E SER EXPULSO DA SOCIEDADE ETERNAMENTE (FUTURO CRACKUDO(OPCIONAL))")
  else:
    print(f"\nCARALHOOOOOOOO voce FEZ OQ NGM NUNCA CONSEGUE FAZER NO DIA A DIA!!! QUITAR AS DIVIDAS(FICAR NO AZUL(OPCIONAL))")

  input("gostou do jogo?")




### ---- BrasaWood ---- ###
#-Perssonagens
personagens2 = {
    "Aprendiz Arqueiro: ": {"vida": 200, "atque": 100, "defesa": 150, "lore": "🏹 Elara (Arqueira): Sobrevivente das ruas que caçava ratos para não morrer de fome. É solitária \ne precisa do tesouro para nunca mais ter que se esconder ou passar necessidade.\n\n"},
    "Aprendiz Espadachim": {"vida": 150, "ataque": 150, "defesa": 200, "lore": "⚔️ Kaelen (Espadachim): Ex-servo humilhado por nobres que aprendeu a lutar \ncom a mão esquerda após ter a direita quebrada. Busca o tesouro para comprar \na liberdade de sua mãe.\n\n"},
    "Aprendiz Mago": {"vida": 100, "ataque": 200, "defesa": 250, "lore":"🔮 Lyra (Maga): Viveu trancada em um porão por anos porque sua vila temia seus poderes. \nBusca o tesouro para criar um santuário onde pessoas com magia sejam aceitas.\n\n"},
    "Aventureiro da Floresta Negra": {"vida": 120, "ataque": 120, "defesa": 250, "lore": "🌲 Finn (Aventureiro): O único com infância feliz e pais amorosos. É um explorador nato \nque busca o tesouro pela sede de aventura e para provar que é mais que um lenhador.\n\n" },
    "Aprendiz das Artes Marciais": {"vida": 150, "ataque": 200, "defesa": 250, "lore": "👊 Ren (Artes Marciais): Órfão de templo que sofria bullying e aprendeu \na lutar usando a determinação em vez da força. Busca o tesouro para descobrir \nsua verdadeira origem.\n\n"},
    "Elfo": {"vida": 100, "ataque": 90, "defesa": 100, "lore": "🧝 Sylas (Elfo): Nobre decaído que vive no escuro. Busca o tesouro para levar sua família de volta ao sol."}
}


##-Introdução
print(" ༺__Bem Va Jornada\n\nO Mestre dos Matadores de Monstros foi uma lenda. Dizem que ele acumulou riquezas inimagináveis,\nescondidas no coração da Floresta Negra, um lugar onde a própria luz do sol teme entrar.\n Para os pobres e esquecidos do reino, esse tesouro não\né apenas ouro; é a liberdade. É a chance de reescrever uma história que\ncomeçou com dor e privação.Cinco jovens, cada um vindo de um canto \ndiferente e cruel do reino, decidiram que suas vidas valiam mais do que a \nmiséria em que nasceram. Eles se encontraram nas bordas da floresta, \nunidos por um objetivo comum: sobreviver e enriquecer.\n\n")
escolha1 = input("Escolha sua classe:\n Aprendiz Arqueiro (vida=200, ataque=100, defesa=150)\n Aprendiz Espadachim(vida=150, ataque=150, defesa=200)\n Aprendiz Mago (Vida=150, Ataque=550, defesa=300)\n Aventureiro da Floresta Negra(Vida=120 ataque=120 defesa=250)\n Aprendiz Artes Marciais(vida=120 ataque=200 defesa=250)")
if escolha in personagens2:
  jogador1 = personagens2[escolha1]
  print(f"classe {escolha1} selecionada!!!\n\n{personagens2[escolha1]["lore"]}")
else:
  print(f"Não entendem+os oq quis dizer, vc foi selecionado para ser um Elfo.\n\n{personagens2['Elfo']['lore']}")

###-Inimigos
inimigo1 = {"nome": "Goblin de Terra", "vida": 400, "ataque": 50,}
inimigo2 = {"nome": "Lobo das Montalhas", "vida": 550, "ataque": 120}
inimigo3 = {"nome": "Urso Mutante", "vida": 700, "ataque":250}
inimigo4 = {"nome": "Tigre Dente de Titanium", "vida": 1000, "ataque":500}

####-Primeira fase
print("")
while jogador1['vida'] > 0 and inimigo1['vida'] > 0:
# Out:
#   File "/tmp/ipykernel_3391/546666593.py", line 60
#     while jogador:
#     ^
# IndentationError: expected an indented block after 'else' statement on line 58

# %%
print("Não entendemos oq quis dizer, vc foi selecionado para ser um Elfo.\n\n"{elfo["lore"]})
  elfo = {"vida": 100, "ataque": 90, "defesa": 100, "lore": "🧝 Sylas (Elfo): Nobre decaído que vive no escuro. Busca o tesouro para levar sua família de volta ao sol."}
# Out:
#   File "/tmp/ipykernel_3391/1807401464.py", line 1
#     print("Não entendemos oq quis dizer, vc foi selecionado para ser um Elfo.\n\n"{elfo["lore"]})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
