# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCapComp/Atividades/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1 = input(print('digite um numero'))
n2 = input(print('digite outro numero'))
media = float(n2 + n1)/2
print (f"a média é igual a:")
print (media)
# Out:
# digite um numero
# None80
# digite outro numero
# None56
# a média é igual a:
# 2840.0

# %%
n1 = 8
n2 = 6
media = (n1 + n2) / 2

print("Sua média atual é:")
print(media)
# Out:
# Sua média atual é:
# 7.0

# %%
Ferramentas = ["martelo", "Parafal", "AK-47"]
print(Ferramentas[0])
print(Ferramentas[2])
Ferramentas.append("Colt 45")
print(Ferramentas[3])
# Out:
# martelo
# AK-47
# Colt 45

# %%
Moto = {
    "Marca":"Honda",
    "Modelo":"start 160",
    "ano": "1990",
}
print(Moto["Modelo"])
print(Moto["ano"])
# Out:
# start 160
# 1990

# %%
idade = int(input(print("digite sua idade: ")))

if (idade) >= 18:
  print("acesso permitido")
elif (idade) <= 18:
  falta = 18 - (idade)
  print(f"falta {falta} para vc acessar ")
else:
  print("acesso negado")
# Out:
# digite sua idade:
# None43
# acesso permitido

# %%
preços = [9.90, 15.50, 99.99 ]
for p in preços:
  print(f"O valor de desconto é: {p * 0.9} ")
# Out:
# O valor de desconto é: 8.91
# O valor de desconto é: 13.950000000000001
# O valor de desconto é: 89.991

# %%
matriz = [
    [1, 2, 3], # Linha 0
    [0, 5, 6], # Linha 1
    [7, 8, 9]  # Linha 2
]
print(matriz[1][2])
# Out:
# 6

# %%
def calcular_area(largura, altura):
  area = altura * largura
  return area

resultado = calcular_area(5, 10)
print(f"sua area é de: {resultado}m2")
# Out:
# sua area é de: 50m2

# %%
def calcular_area(largura, altura):
  area = altura * largura
  return area

r1 = float(input("digite a largura de sua area: "))
r2 = float(input("digite a altura da sua area: "))
resp = calcular_area(r1, r2)
print(f"sua área é de:{resp}m2 ")
# Out:
# digite a largura de sua area: 32
# digite a altura da sua area: 43
# sua área é de:1376.0m2

# %%
from re import S
print("\nBem vindo ao sites de lanças\n")
nome = input("digite seu nome: ")
idade = int(input("Digite sua idade: "))
cpf = int(input("digite seu cpf: "))

if idade > 18:
  print("\nparabéns, acesso permitido!!!\n")
elif idade < 18:
  print("aesso negado")
else:
  cpfs = []
  cpfs.append(cpf)
  print(f"numero de cadastro de cpfs: {cpfs[0]}")

def produtos():
  matriz = [
    ["lança foguete por R$4.000"],
    ["Lança granada por R$3.000"],
    ["Lança flecha por R$2.000"],
    ["Lança por R$1.000"],
    ["Lança perfume por R$120"]
  ]

print("Conheça Nossos produtos:")
for p in matriz:
  print(f"{p}")



prod1 = int(input("\nEscolha a numeração do seu produto\n1=lança foguete\n2=Lança granada\n3=Lança flecha\n4=Lança\n5=Lança perfume\n "))

if prod1 == 1:
  confirmar = (input("vc escolheu Lança Foguete\n sua compra ficará R$ 4.000\n deseja comprar mais alguma coisa?(s/n)"))
  if confirmar == 's':
    print("compra bem sucedida")
  else:
    print("compra cancelada pelo usuario")
    produtos

elif prod1 == 2:
  input("voce escolheu o lança granada\nsua compra ficará RE3.000\ndeseja comprar mais alguma coisa?")
elif prod1 == 3:
  input("voce escolheu o lança flec1ha\n sua compra ficaraá R$2.000\ndeseja comprar mais alguma coisa?")
elif prod1 == 4:
  input("voce escolheu a lança\n sua compra ficará R$1.000\n deseja comprar mais alguma coisa?")
elif prod1 == 5:
  input("voce escolheu o lança perfume\n sua compra ficará R$120,00\n deseja comprar mais alguma coisa?")
else:
  print("o astralopitecos, vc é burro ou n sabe ler? ou é os dois?")
# Out:
# Bem vindo ao sites de lanças
#
# digite seu nome: jota
# Digite sua idade: 1231
# digite seu cpf: 123
#
# parabéns, acesso permitido!!!
#
# Conheça Nossos produtos:
# ['lança foguete por R$4.000']
# ['Lança granada por R$3.000']
# ['Lança flecha por R$2.000']
# ['Lança por R$1.000']
# ['Lança perfume por R$120']
#
# Escolha a numeração do seu produto
# 1=lança foguete
# 2=Lança granada
# 3=Lança flecha
# 4=Lança
# 5=Lança perfume
#  1
# vc escolheu Lança Foguete
#  sua compra ficará R$ 4.000
#  deseja comprar mais alguma coisa?(s/n)n
# compra cancelada pelo usuario
