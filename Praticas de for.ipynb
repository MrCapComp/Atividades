# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCapComp/Atividades/blob/main/Praticas%20de%20for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "jotta"
idade = 19
altura = 1.82
cidade = "BH"
print("meu nome é", nome)
print(f"moro em", cidade)
print(f"tenho", idade, "anos e", altura, "de altura")
# Out:
# meu nome é jotta
# moro em BH
# tenho 19 anos e 1.82 de altura

# %%
nome = input("digite seu nome: ")
print("olá", nome)
# Out:
# digite seu nome: lol
# olá lol

# %%
idade = int(input("digite sua idade para saber quantos anos terá daq 7 anos: "))
soma = idade + 7
print(f"vc terá", soma, "de idade")
# Out:
# digite sua idade para saber quantos anos terá daq 7 anos: 90
# vc terá 97 de idade

# %%
n1 = int(input("digite um numero: "))
n2 = int(input("digite utro numero: "))
soma = n1 + n2
subtração = n1 - n2
multiplicação = n1 * n2
divisão = n1 % n2
potencia = n1 ** n2
print(f"A soma dos numeros dá:", soma)
print(f"A subtração dos nunmeros dá:", subtração)
print(f"A Multiplicação dos numero d´:", multiplicação)
print(f"A divisão dos numeros dá:", divisão)
print(f"a potencia dos numeros dá:", potencia)
# Out:
# digite um numero: 5
# digite utro numero: 4
# A soma dos numeros dá: 9
# A subtração dos nunmeros dá: 1
# A Multiplicação dos numero d´: 20
# A divisão dos numeros dá: 1
# a potencia dos numeros dá: 625

# %%
n1 = int(input("digite seu numero: "))
doisv = n1 * 2
tresv = n1 * 3
quatrov = n1 * 4
print(f"dobro:", doisv, "triplo:", tresv, "quadruplo", quatrov)
# Out:
# digite seu numero: 2
# dobro: 4 triplo: 6 quadruplo 8

# %%
n1 = int(input("digite um numero: "))
if n1 % 2 == 0:
  print("seu numero é par")
else:
  print("é impar patrão")
# Out:
# digite um numero: 6
# seu numero é par

# %%
idade = int(input("digite sua idade: "))
if idade >= 18:
  print("se dirvita la encima meu patrão")
else:
  print("oz só pode entrar dmaior, o puteiro n permite dmenor")
# Out:
# digite sua idade: 18
# se dirvita la encima meu patrão

# %%
print(10 + 5 * 2)
# Out:
# 20

# %%
nota = int(input("digite a bnota do aluno: "))
if nota >= 7:
  print("acima da média")
elif nota <= 7:
   print("abaixo da média")
else:
  print("consegui ler n")
# Out:
# digite a bnota do aluno: 8
# acima da média

# %%
idade = int(input("digite sua idade: "))
carteira = input("term carteira?:(s/n)")

if idade >= 18 and carteira == "s":
  print("pode dirigir jgdr")
else:
  print("pode nao man]")
# Out:
# digite sua idade: 19
# term carteira?:(s/n)s
# pode dirigir jgdr

# %%
idade = int(input("digite sua idade: "))
if idade >= 18 or idade <= 60:
  print("oc é adulto")
else:
  print("ou c é criança ou c é véi")
# Out:
# digite sua idade: 12
# oc é adulto

# %%
usu = input("digite seu usuario: ")
senh = int(input("digite sua senha: "))
usuario = "jotta"
senha = 123123
if usu == usuario and senh == senha:
  print("bem vindo")
else:
  print("login invalido")
# Out:
# digite seu usuario: jotta
# digite sua senha: 123123
# bem vindo

# %%
idade = int(input("digite sua idade: "))

if idade >= 18 or idade <= 16:
    print("Pode votar")
else:
  print("voltta não")
# Out:
# digite sua idade: 20
# Pode votar

# %%
for i in range(10, 1, -1):
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
n1 = int(input("digite um numero: "))
for i in range(1, n1 + 1):
  print(i)
# Out:
# digite um numero: 8
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
