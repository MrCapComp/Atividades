# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCapComp/Atividades/blob/main/Praticas%20de%20for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = (input("Digite 'rp' para repetir um numero e 'rs' para contar até este número: "))

if n == 'rp':
  n1 = int(input("digite o nuero q quer reptir: "))
  for i in range(n1):
    print(f"{n1}")
elif n == 'rs':
  n2 = int(input("digite o numero q quer contar: "))
  for i in range(1, n2 + 1):
    print(f"{i}")
else:
  print("digite 'rp' ou 'rs'.")
# Out:
# Digite 'rp' para repetir um numero e 'rs' para contar até este número: rp
# digite o nuero q quer reptir: 6
# 6
# 6
# 6
# 6
# 6
# 6

# %%
contador = 0
if i in range(n):
  n = int(input("digite um numero: "))
  if n % 2 == 0:
    contador += n
print(f"quantidade de numeros parer igual a: {i}")
# Out:
# digite um numero: 7
# quantidade de numeros parer igual a: 1

# %%
n = int(input("fala algum numero: "))
for i in range(1, n):
  print(f"{i}")
# Out:
# fala algum numero8
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
n = int(input("Digite um numero:"))
for i in range(n):
  if i % 2 == 0:
    print(f"{i}")
# Out:
# Digite um numero:8
# 0
# 2
# 4
# 6

# %%
soma = 2
for i in range(soma):
  soma += 9
print(soma)
# Out:
# 20

# %%
n = int(input("digite um numero: "))
for i in range(1, n+1):
  print(i)
# Out:
# digite um numero: 8
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
n = int(input("digite um numero: "))
soma = 0
for i in range(n):
  numero = int(input("digite: "))
  soma += numero
print(f"total", soma)
# Out:
# digite um numero: 9
# que numero: 8
# que numero: 8
# que numero: 8
# que numero: 8
# que numero: 88
# que numero: 8
# que numero: 8
# que numero: 8
# que numero: 8
# total 152

# %%
n = int(input("Digite o numero de notas: "))
soma = 0
for i in range(n):
  n2 = float(input("Digite o valor das notas: "))
  soma += n2
print(f"total:", soma)
# Out:
# Digite o numero de notas: 5
# Digite o valor das notas: 6.0
# Digite o valor das notas: 57.50
# Digite o valor das notas: 34
# Digite o valor das notas: 25
# Digite o valor das notas: 99.99
# total: 222.49

# %%
n = int(input("digite "))

# %%
n = int(input("digite numeros: "))
for i in range(n):
  if i % 2 == 0:
    print({i})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8454/135659429.py in <cell line: 0>()
# ----> 1 n = int(input("digite numeros: "))
#       2 for i in range(n):
#       3   if i % 2 == 0:
#       4     print({i})
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
n = int(input("digite numero: "))
for i in range(n):
  if i % 2 == 0:
    print(f"{i}")
# Out:
# digite numero: 4
# 0
# 2

# %%
n1 = int(input("digite o numero de notas: "))
soma = 0
for i in range(n1):
  numero = float(input("digite o valor das notas"))
  soma += numero
print(f"deu", soma)
# Out:
# digite o numero de notas: 3
# digite o valor das notas2
# digite o valor das notas2
# digite o valor das notas2
# deu 6.0

# %%
n1 = int(input("digite a quantidade de numeros: "))
for i in range (n1):
  if i % 2 == 0:
    print(i)
# Out:
# digite a quantidade de numeros: 6
# 0
# 2
# 4

# %%
n1 = int(input("digite a quantidade de notas: "))
soma = 0
for i in range(n1):
  n2 = float(input("Digite o valor (R$) das notas:"))
  soma += n2
print("R$", soma)
# Out:
# digite a quantidade de notas: 2
# Digite o valor (R$) das notas:50
# Digite o valor (R$) das notas:50
# R$ 100.0

# %%
n1 = int(input("DIGITE algum numero: "))
for i in range(n, 0, -1):
  print(i)
# Out:
# DIGITE algum numero: 8
# 4
# 3
# 2
# 1

# %%
n1 = int(input("digite um numero: "))
for i in range(n1):
  if i % 2 == 0:
    print(f"cole ze {i}")
# Out:
# digite um numero: 8
# cole ze 0
# cole ze 2
# cole ze 4
# cole ze 6

# %%
soma = 0
for i in range(2):
  n1 = int(input("digite um numero: "))
  if n1 > 0:
    soma += n1
print("soma", soma)
# Out:
# digite um numero: 3
# digite um numero: 4
# soma 7

# %%
soma = 0
for i in range(2):
  n1 = int(input("digite um numero: "))
  if n1 > 0:
    soma += n1
print("soma", soma)
# Out:
# digite um numero: 7
# digite um numero: 8
# soma 15

# %%
soma = 0
for i in range(2):
  n1 = int(input("digite um numero: "))
  if n1 == 0:
    soma += n1
print("soma", soma)

# %%
n1 = int(input("digite q quaitidade de notas: "))
soma = 0
for i in range(n1):
  n2 = int(input("digite o valor das notas: "))
  soma += n2
print("soma,", soma)
# Out:
# digite q quaitidade de notas: 3
# digite o valor das notas: 1
# digite o valor das notas: 1
# digite o valor das notas: 1
# soma, 3

# %%
n1 = int(input("digite a quatidade de notas: "))
soma = 0
for i in range(n1):
  n2 = float(input("digite o valor das notas: "))
  soma += n2
print('soma, ', soma)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8454/3549775580.py in <cell line: 0>()
# ----> 1 n1 = int(input("digite a quatidade de notas: "))
#       2 soma = 0
#       3 for i in range(n1):
#       4   n2 = float(input("digite o valor das notas: "))
#       5   soma += n2
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
n1 = int(input("digite um numero: "))
for i in range(1, 11):
  print(f"{n1} x {i} = {n1*i}")
# Out:
# digite um numero: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
n1 = int(input("digite o valor das notas: "))
n2 = int(input("diite aquantidade de notas: "))
soma = 0
for i in range(n):
  n2= int(input("digite o valor nas notas"))
  soma += n1
print("soma,",soma)
# Out:
# digite a quantidade de notas: 2
# digite o valor nas notas2
# digite o valor nas notas2
# soma, 4
